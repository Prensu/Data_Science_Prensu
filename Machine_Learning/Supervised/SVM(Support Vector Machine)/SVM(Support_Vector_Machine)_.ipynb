# %%
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
df=pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %%
df['target']=iris.target.  # here i am concatenating target column

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df[df.target==0].head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df[df.target==0].tail()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 45                4.8               3.0                1.4               0.3
# 46                5.1               3.8                1.6               0.2
# 47                4.6               3.2                1.4               0.2
# 48                5.3               3.7                1.5               0.2
# 49                5.0               3.3                1.4               0.2
#
#     target
# 45       0
# 46       0
# 47       0
# 48       0
# 49       0

# %%
df[df.target==1].head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target
# 50       1
# 51       1
# 52       1
# 53       1
# 54       1

# %%
df[df['target']==1].tail()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 95                5.7               3.0                4.2               1.2
# 96                5.7               2.9                4.2               1.3
# 97                6.2               2.9                4.3               1.3
# 98                5.1               2.5                3.0               1.1
# 99                5.7               2.8                4.1               1.3
#
#     target
# 95       1
# 96       1
# 97       1
# 98       1
# 99       1

# %%
df[df.target==2].head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target
# 100       2
# 101       2
# 102       2
# 103       2
# 104       2

# %%
df[df['target']==2].tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df0=df.target==0
df1=df['target']==1
df2=df['target']==2

# %%
df0.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: target, dtype: bool

# %%
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.scatter(df[df0]['sepal length (cm)'], df[df0]['sepal width (cm)'], color='green', marker='+')
plt.scatter(df[df1]['sepal length (cm)'], df[df1]['sepal width (cm)'], color='blue', marker='o')
# Out:
# <ipython-input-31-3fcfff18a187>:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.xlabel('petal length')
plt.ylabel('petal width')
plt.scatter(df[df0]['petal length (cm)'], df[df0]['petal width (cm)'], color='green', marker='+')
plt.scatter(df[df1]['petal length (cm)'], df[df1]['petal width (cm)'], color='blue', marker='o')

# %%
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.scatter(df[df0]['sepal length (cm)'], df[df0]['sepal width (cm)'], color='green', marker='+')
plt.scatter(df[df1]['sepal length (cm)'], df[df1]['sepal width (cm)'], color='blue', marker='o')
plt.scatter(df[df2]['sepal length (cm)'], df[df2]['sepal width (cm)'], color='red', marker='*')

# %%
from sklearn.model_selection  import train_test_split

# %%
X=df.drop(['target'],axis='columns')
y=df.target

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y.tail()
# Out:
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(df,y,test_size=0.2)

# %%
len(X_train)
# Out:
# 120

# %%
len(y_train)
# Out:
# 120

# %%
len(X_test)
# Out:
# 30

# %%
from sklearn.svm import SVC
model=SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
model.score(X_test,y_test)
# Out:
# 1.0
