# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('netflix_titles.csv')

# %%
df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %% [markdown]
# #### Let's check for null values

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(df.isnull(),cmap='viridis')
# Out:
# <Axes: >

# %%
df['rating'].value_counts().unique()
# Out:
# array([2027, 1698,  701,  508,  286,  218,  184,  169,  149,  143,   95,
#          37,    7,    2], dtype=int64)

# %%
df['rating'].value_counts().nunique()
# Out:
# 14

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       2027
# TV-14       1698
# TV-PG        701
# R            508
# PG-13        286
# NR           218
# PG           184
# TV-Y7        169
# TV-G         149
# TV-Y         143
# TV-Y7-FV      95
# G             37
# UR             7
# NC-17          2
# Name: count, dtype: int64

# %%
df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %% [markdown]
# In the above data, we can choose to drop the director and cast columns completely as they are not a huge part for us while we visualize the data and they dont add any significant value to our analysis. We are only focused on visualizing this data hence dropping two columns wont be any trouble for us.But this should not be a regular practise as if we are making a recommender system, we cannot drop the director and cast of a movie as these are a key feature used to recommend movies to users

# %%
df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
df['listed_in'].value_counts()
# Out:
# listed_in
# Documentaries                                       299
# Stand-Up Comedy                                     273
# Dramas, International Movies                        248
# Dramas, Independent Movies, International Movies    186
# Comedies, Dramas, International Movies              174
#                                                    ...
# TV Comedies, TV Dramas, TV Mysteries                  1
# Classic Movies, Dramas, LGBTQ Movies                  1
# Crime TV Shows, TV Dramas, TV Sci-Fi & Fantasy        1
# Docuseries, Reality TV, Teen TV Shows                 1
# Reality TV, Spanish-Language TV Shows                 1
# Name: count, Length: 461, dtype: int64

# %% [markdown]
# #### For House of cards , what is the show id and who is the director ?

# %%
house_of_cards=df['title']=='House of Cards'

# %%
house_of_cards.value_counts()
# Out:
# title
# False    6233
# True        1
# Name: count, dtype: int64

# %%
df[house_of_cards]
# Out:
#        show_id     type           title director  \
# 5741  70178217  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 5741  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#              date_added  release_year rating   duration  \
# 5741   November 2, 2018          2018  TV-MA  6 Seasons
#
#                     listed_in  \
# 5741  TV Dramas, TV Thrillers
#
#                                             description
# 5741  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ##### Another Method

# %%
df.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description
# 0  Before planning an awesome wedding for his gra...
# ...

# %%
df['title']
# Out:
# 0           Norm of the North: King Sized Adventure
# 1                        Jandino: Whatever it Takes
# 2                                Transformers Prime
# 3                  Transformers: Robots in Disguise
# 4                                      #realityhigh
#                            ...
# 6229                                   Red vs. Blue
# 6230                                          Maron
# 6231         Little Baby Bum: Nursery Rhyme Friends
# 6232    A Young Doctor's Notebook and Other Stories
# 6233                                        Friends
# Name: title, Length: 6234, dtype: object

# %%
df[df['title'].isin(['House of Cards'])]
# Out:
#        show_id     type           title director  \
# 5741  70178217  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 5741  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#              date_added  release_year rating   duration  \
# 5741   November 2, 2018          2018  TV-MA  6 Seasons
#
#                     listed_in  \
# 5741  TV Dramas, TV Thrillers
#
#                                             description
# 5741  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ##### Another Method using str.contains()

# %%
df[df['title'].str.contains('House of Cards')]
# Out:
#        show_id     type           title director  \
# 5741  70178217  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 5741  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#              date_added  release_year rating   duration  \
# 5741   November 2, 2018          2018  TV-MA  6 Seasons
#
#                     listed_in  \
# 5741  TV Dramas, TV Thrillers
#
#                                             description
# 5741  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### In which year the highest number of TV shows & Movies were released ? Show them with bar graph!

# %%
df['release_year']
# Out:
# 0       2019
# 1       2016
# 2       2013
# 3       2016
# 4       2017
#         ...
# 6229    2015
# 6230    2016
# 6231    2016
# 6232    2013
# 6233    2003
# Name: release_year, Length: 6234, dtype: int64

# %%
df['release_year'].value_counts()
# Out:
# release_year
# 2018    1063
# 2017     959
# 2019     843
# 2016     830
# 2015     517
#         ...
# 1966       1
# 1959       1
# 1964       1
# 1925       1
# 1963       1
# Name: count, Length: 72, dtype: int64

# %%
df['release_year'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='release_year'>

# %%
#Another method 
df.dtypes
# Out:
# show_id          int64
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df['Date_N']=pd.to_datetime(df['release_year'])

# %%
df['Date_N']
# Out:
# 0      1970-01-01 00:00:00.000002019
# 1      1970-01-01 00:00:00.000002016
# 2      1970-01-01 00:00:00.000002013
# 3      1970-01-01 00:00:00.000002016
# 4      1970-01-01 00:00:00.000002017
#                     ...
# 6229   1970-01-01 00:00:00.000002015
# 6230   1970-01-01 00:00:00.000002016
# 6231   1970-01-01 00:00:00.000002016
# 6232   1970-01-01 00:00:00.000002013
# 6233   1970-01-01 00:00:00.000002003
# Name: Date_N, Length: 6234, dtype: datetime64[ns]

# %%
df.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %% [markdown]
# df.dtypes

# %%
df['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 1970    6234
# Name: count, dtype: int64

# %%
#i have left this question because in excel file the release date and date_added are in different columns whereas the solution has been done when combination of both

# %% [markdown]
# ### How many movies and tv shows are there in dataset ? Show with bar graph

# %%
df['type'].value_counts()
# Out:
# type
# Movie      4265
# TV Show    1969
# Name: count, dtype: int64

# %%
df['type'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='type'>

# %% [markdown]
# ##### We can also use groupby function in this case

# %%
df.groupby('type').type.count()
# Out:
# type
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %%
df.groupby('type').type.count().plot(kind='bar')
# Out:
# <Axes: xlabel='type'>

# %%
sns.countplot(df['type'])
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %% [markdown]
# ### show all the movies releaed in 2000

# %%
df.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %%
df['release_year']==2000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6229    False
# 6230    False
# 6231    False
# 6232    False
# 6233    False
# Name: release_year, Length: 6234, dtype: bool

# %%
all_movies=(df['release_year']==2000)

# %%
all_movies.value_counts()
# Out:
# release_year
# False    6203
# True       31
# Name: count, dtype: int64

# %%
#i don't  know why but my datetime is not being correct !

# %%
movie_2000=(df['type']=='Movie')&(df['release_year']==2000)

# %%
movie_2000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6229    False
# 6230    False
# 6231    False
# 6232    False
# 6233    False
# Length: 6234, dtype: bool

# %%
movie_2000.value_counts()
# Out:
# False    6206
# True       28
# Name: count, dtype: int64

# %%
df[movie_2000]
# Out:
#        show_id   type                                              title  \
# 108   60003155  Movie                             Joseph: King of Dreams
# 300   60000861  Movie                                    American Psycho
# 609   70118859  Movie             Monty Python: Before the Flying Circus
# 785   60003242  Movie                                   Charlie's Angels
# 818   60003540  Movie                        Rugrats in Paris: The Movie
# 832   60000921  Movie                 The Flintstones in Viva Rock Vegas
# 1186  60003508  Movie                                           The Gift
# 2298  60002907  Movie                     Crouching Tiger, Hidden Dragon
# 2340  60003401  Movie                          Hamara Dil Aapke Paas Hai
# 2365  60037397  Movie                                              Pukar
# 2735  60000901  Movie                     How the Grinch Stole Christmas
# 3074  60000415  Movie                                           Scream 3
# ...

# %% [markdown]
# #### Show the titles of tv shows releaed only in india

# %%
dhoti_movies=(df['country']=='India')

# %%
dhoti_movies.value_counts()
# Out:
# country
# False    5457
# True      777
# Name: count, dtype: int64

# %%
df[dhoti_movies]
# Out:
#        show_id     type                                              title  \
# 35    81154455    Movie                                         Article 15
# 37    81052275    Movie                              Ee Nagaraniki Emaindi
# 41    70303496    Movie                                                 PK
# 58    81155784    Movie                                           Watchman
# 99    80225885  TV Show                                      Bard of Blood
# ...        ...      ...                                                ...
# 5573  80171439    Movie  The Human Factor: The Untold Story of the Bomb...
# 5708  81011159  TV Show                                      Little Things
# 5839  80178836  TV Show                             The House That Made Me
# 5867  80207879  TV Show                                   Sab Jholmaal Hai
# 5923  80122239  TV Show                                Pyaar Tune Kya Kiya
#
#                      director  \
# 35              Anubhav Sinha
# ...

# %%
#but we want the tv shows only so let's filter it

# %%
dhoti_movies=(df['country']=='India')&(df['type']=='TV Show')

# %%
df[dhoti_movies]
# Out:
#        show_id     type                                    title  \
# 99    80225885  TV Show                            Bard of Blood
# 648   81020066  TV Show              Mighty Little Bheem: Diwali
# 689   81006356  TV Show            Devlok with Devdutt Pattanaik
# 789   81113888  TV Show                          College Romance
# 793   81113890  TV Show                        Engineering Girls
# 797   81113886  TV Show                             Girls Hostel
# 804   81113887  TV Show                                  Inmates
# 1653  81132060  TV Show                                Thackeray
# 1762  80122237  TV Show                          Classic Legends
# 1838  80229034  TV Show              Anjaan: Special Crimes Unit
# 1850  80229102  TV Show                 Khan: No. 1 Crime Hunter
# 1998  80170381  TV Show    Th Eena Meena Deeka Chase Comedy Show
# 2090  81076756  TV Show                              Delhi Crime
# ...

# %%
df[dhoti_movies].shape
# Out:
# (53, 13)

# %%
#also we want the titles only so let's do some changes

# %%
df[dhoti_movies]['title']
# Out:
# 99                                Bard of Blood
# 648                 Mighty Little Bheem: Diwali
# 689               Devlok with Devdutt Pattanaik
# 789                             College Romance
# 793                           Engineering Girls
# 797                                Girls Hostel
# 804                                     Inmates
# 1653                                  Thackeray
# 1762                            Classic Legends
# 1838                Anjaan: Special Crimes Unit
# 1850                   Khan: No. 1 Crime Hunter
# 1998      Th Eena Meena Deeka Chase Comedy Show
# 2090                                Delhi Crime
# 2200                              Khotey Sikkey
# 2210                                 Rishta.com
# 2297              Cricket Fever: Mumbai Indians
# 2333                       Darr Sabko Lagta Hai
# 2359                                   Mahi Way
# 2661                                      Leila
# 2718                  Gabru: Hip Hop Revolution
# ...

# %% [markdown]
# ### show top 10 directors who gave the highest number of TV Shows and movies to Netflix

# %%
df['director'].value_counts()
# Out:
# director
# Raúl Campos, Jan Suter         18
# Marcus Raboy                   14
# Jay Karas                      13
# Jay Chapman                    12
# Steven Spielberg                9
#                                ..
# Peter Mortimer, Josh Lowell     1
# Greg Coolidge                   1
# Owen Egerton                    1
# Sam "Blitz" Bazawule            1
# Onur Ünlü                       1
# Name: count, Length: 3301, dtype: int64

# %%
df['director'].value_counts().head(10)
# Out:
# director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              14
# Jay Karas                 13
# Jay Chapman               12
# Steven Spielberg           9
# Martin Scorsese            9
# Lance Bangs                8
# David Dhawan               8
# Johnnie To                 8
# Shannon Hartman            7
# Name: count, dtype: int64

# %% [markdown]
# ### show all the record where 'category is movie and type is comedies' or 'Country is United Kingdom'

# %%
df[(df['type']=='Movie')&(df['listed_in']=='Comedies') | (df['country']=='United Kingdom')]
# Out:
#        show_id     type                                        title  \
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 4     80125979    Movie                                 #realityhigh
# 42    80162141    Movie                                    Hard Tide
# 43    80095641    Movie                                 Elstree 1976
# 62    81054495    Movie                        Mo Gilligan: Momentum
# ...        ...      ...                                          ...
# 6180  70250398  TV Show                                        Vexed
# 6186  70258489  TV Show                                        Derek
# 6190  80130911  TV Show                                  Chewing Gum
# 6204  80091341  TV Show                                       Cuckoo
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
#
#                              director  \
# 1                                 NaN
# 4                    Fernando Lebrija
# ...

# %% [markdown]
# ### In how many movies TOM Cruise was cast ?

# %%
#filtering
df.cast
# Out:
# 0       Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                        Jandino Asporaat
# 2       Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3       Will Friedle, Darren Criss, Constance Zimmer, ...
# 4       Nesta Cooper, Kate Walsh, John Michael Higgins...
#                               ...
# 6229    Burnie Burns, Jason Saldaña, Gustavo Sorola, G...
# 6230    Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...
# 6231                                                  NaN
# 6232    Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...
# 6233    Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...
# Name: cast, Length: 6234, dtype: object

# %%
df.cast.head(2)
# Out:
# 0    Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                     Jandino Asporaat
# Name: cast, dtype: object

# %%
df[df['cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N]
# Index: []

# %% [markdown]
# since there are other cast with tom cruise so its not showing

# %%
#so let's use contains
data_new=df.dropna()

# %%
data_new.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 4  80125979  Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 4                             United States  September 8, 2017          2017
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 4  TV-14   99 min                            Comedies
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#        show_id   type     title              director  \
# 3071  60029369  Movie  Rain Man        Barry Levinson
# 3538  60000440  Movie  Magnolia  Paul Thomas Anderson
#
#                                                    cast        country  \
# 3071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
# 3538  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
#
#            date_added  release_year rating duration  \
# 3071     July 1, 2019          1988      R  134 min
# 3538  January 1, 2020          1999      R  189 min
#
#                        listed_in  \
# 3071      Classic Movies, Dramas
# 3538  Dramas, Independent Movies
#
#                                             description  \
# 3071  A fast-talking yuppie is forced to slow down w...
# 3538  Through chance, human action, past history and...
#
#                             Date_N
# 3071 1970-01-01 00:00:00.000001988
# 3538 1970-01-01 00:00:00.000001999

# %% [markdown]
# ### what are the different ratings given by Netflix

# %%
df['rating'].nunique()
# Out:
# 14

# %%
df['rating'].unique()
# Out:
# array(['TV-PG', 'TV-MA', 'TV-Y7-FV', 'TV-Y7', 'TV-14', 'R', 'TV-Y', 'NR',
#        'PG-13', 'TV-G', 'PG', 'G', nan, 'UR', 'NC-17'], dtype=object)

# %% [markdown]
# ### How many movies got TV-14 rating in canada

# %%
df[(df['rating']=='TV-14')&(df['country']=='Canada')]
# Out:
#        show_id     type                                              title  \
# 726   80990869    Movie        Martin Matte: La vie, la mort...eh la la..!
# 1324  80205085    Movie                                  Long Time Running
# 1900  80178720    Movie                                         Kiss & Cry
# 2307  80202258  TV Show                                    Northern Rescue
# 2620  81136963    Movie                               The Wrong Babysitter
# 2631  81123051    Movie                                  3 Seconds Divorce
# 2705  81070008    Movie  Prosecuting Evil: The Extraordinary World of B...
# 3083  81017506    Movie                        The Accountant of Auschwitz
# 3099  80997402    Movie                         Counterfeiting in Suburbia
# 3976  70137744    Movie                     Rush: Beyond the Lighted Stage
# 4332  81029400    Movie                                     At First Light
# ...

# %%
df[(df['rating']=='TV-14')&(df['country']=='Canada')&(df['type']=='Movie')].shape
# Out:
# (13, 13)

# %% [markdown]
# #### How many movies got R rating after the year 2018

# %%
df[(df['type']=='Movie')&(df['rating']=='R')&(df['release_year']>2018)]
# Out:
#        show_id   type                                       title  \
# 87    80200087  Movie                                      Domino
# 125   81053953  Movie                     Inside Man: Most Wanted
# 529   80182014  Movie                         Dolemite Is My Name
# 654   80994011  Movie                              The Laundromat
# 1038  81053961  Movie                        Undercover Brother 2
# 1100  80175798  Movie                                The Irishman
# 1264  80244457  Movie                             Earthquake Bird
# 1419  80182016  Movie                                    The King
# 1625  81028570  Movie  Extremely Wicked, Shockingly Evil and Vile
# 1773  81053958  Movie                                 Backdraft 2
# 1807  80194950  Movie                                Wine Country
# 2051  80200571  Movie                              The Highwaymen
# 2239  80192187  Movie                             Triple Frontier
# ...

# %% [markdown]
# ### What is the maximum duration of a movie show in netflix

# %%
df.duration.unique()
# Out:
# array(['90 min', '94 min', '1 Season', '99 min', '110 min', '60 min',
#        '78 min', '95 min', '58 min', '62 min', '65 min', '61 min',
#        '135 min', '98 min', '96 min', '79 min', '113 min', '80 min',
#        '77 min', '112 min', '106 min', '102 min', '114 min', '125 min',
#        '142 min', '133 min', '100 min', '86 min', '146 min', '10 min',
#        '122 min', '126 min', '116 min', '130 min', '70 min', '128 min',
#        '88 min', '108 min', '93 min', '64 min', '107 min', '92 min',
#        '111 min', '103 min', '40 min', '85 min', '72 min', '45 min',
#        '89 min', '24 min', '127 min', '163 min', '117 min', '42 min',
#        '104 min', '75 min', '82 min', '38 min', '97 min', '81 min',
#        '91 min', '152 min', '87 min', '121 min', '101 min', '119 min',
#        '83 min', '182 min', '124 min', '63 min', '139 min', '171 min',
#        '84 min', '69 min', '76 min', '41 min', '153 min', '141 min',
# ...

# %%
df.duration.dtypes
# Out:
# dtype('O')

# %% [markdown]
# ##### so, we need to convert this to numeric format

# %%
df[['Minutes', 'Unit']] = df['duration'].str.split(' ', expand=True)

# %% [markdown]
# df[['Minutes', 'Unit']]

# %%
df.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %%
df['Minutes'].max()
# Out:
# '99'

# %% [markdown]
# ### Which individual country has the higest number of TV-Shows

# %%
df[(df['type']=='TV Show')].country.value_counts()
# Out:
# country
# United States                                                  550
# United Kingdom                                                 178
# Japan                                                          129
# South Korea                                                    104
# Taiwan                                                          65
#                                                               ...
# United States, Chile                                             1
# France, United States, Canada                                    1
# United States, New Zealand, Japan                                1
# Italy, South Africa, West Germany, Australia, United States      1
# Cyprus, Austria, Thailand                                        1
# Name: count, Length: 154, dtype: int64

# %%
df.sort_values(by ='release_year',ascending=False).head(10)
# Out:
#        show_id     type                          title  \
# 3467  81011449  TV Show                 Medical Police
# 3249  81006825    Movie  All the Freckles in the World
# 3220  80997687  TV Show                        Dracula
# 3427  81060049    Movie     Leslie Jones: Time Machine
# 3436  80239306  TV Show     The Healing Powers of Dude
# 3195  80233408    Movie          Live Twice, Love Once
# 3189  81039393  TV Show                          Cheer
# 3464  80237329  TV Show               AJ and the Queen
# 3180  81214114    Movie                  Bulletproof 2
# 3466  81183491  TV Show   Jamtara - Sabka Number Ayega
#
#                        director  \
# 3467                        NaN
# 3249               Yibrán Asuad
# 3220                        NaN
# 3427  David Benioff, D.B. Weiss
# 3436                        NaN
# 3195               Maria Ripoll
# 3189                        NaN
# 3464                        NaN
# 3180           Don Michael Paul
# ...

# %% [markdown]
# #### Find all the instances where:
# category is  movie and type is dramas
#
# or
#
# category is TVShow and type is 'KidsTv'

# %%
df[(df['type']=='Movie')&(df['listed_in']=='Dramas')|(df['type']=='TV Show')&
