# %% [markdown]
# # **Pandas**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Basic Operations
#
# 1.   Creating a Data Frame.
# 1.   Performing operations on Rows and Columns.
# 1.   Data Selection, addition, deletion
# 2.   Working with missing data.
# 2.   Renaming the Columns or Indices of a Dataframe.

# %% [markdown]
# ## **1. Creating a pandas DataFrame**

# %%
import pandas as pd

# %%
data = {'Name': ['Ram', 'Hari', 'Gopal', 'Madan', 'Krishna'],
        'Age': [23, 24, 22, 19, 10]}
data
# Out:
# {'Name': ['Ram', 'Hari', 'Gopal', 'Madan', 'Krishna'],
#  'Age': [23, 24, 22, 19, 10]}

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name  Age
# 0      Ram   23
# 1     Hari   24
# 2    Gopal   22
# 3    Madan   19
# 4  Krishna   10

# %% [markdown]
# ## **2. Performing operations on Rows and Columns**

# %%
# Selecting columns
#df['Name','Age']
df[['Name', 'Age']]
# Out:
#       Name  Age
# 0      Ram   23
# 1     Hari   24
# 2    Gopal   22
# 3    Madan   19
# 4  Krishna   10

# %%
# Selecting a row

row = df.loc[0]
row
# Out:
# Name    Ram
# Age      23
# Name: 0, dtype: object

# %%
# data.iloc[row_index, column_index]

df.iloc[2,1]
# Out:
# 22

# %% [markdown]
# ## **3. Data Selection, addition and deletion**

# %%
df[['Age']]
# Out:
#    Age
# 0   23
# 1   24
# 2   22
# 3   19
# 4   10

# %%
del df['Age'] # columns can be deleted like with a dict
df
# Out:
#       Name
# 0      Ram
# 1     Hari
# 2    Gopal
# 3    Madan
# 4  Krishna

# %%
df.insert(1, 'name', df['Name'])
df
# Out:
#       Name     name
# 0      Ram      Ram
# 1     Hari     Hari
# 2    Gopal    Gopal
# 3    Madan    Madan
# 4  Krishna  Krishna

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/survey_results_schema.csv')
df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
df.shape
# Out:
# (85, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Column        85 non-null     object
#  1   QuestionText  85 non-null     object
# dtypes: object(2)
# memory usage: 1.5+ KB

# %%
df.head(3)
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1  MainBranch  Which of the following options best describes ...
# 2    Hobbyist                            Do you code as a hobby?

# %%
df.tail(2)
# Out:
#           Column                                       QuestionText
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...

# %%
df.describe()
# Out:
#             Column                                       QuestionText
# count           85                                                 85
# unique          85                                                 78
# top     Respondent  Which currency do you use day-to-day? If your ...
# freq             1                                                  2

# %%
df['Hobbyist'].value_counts()

# %%
df.loc[0, 'Hobbyist']

# %%
# print the hobbyist value of the 0,1,2 index data
# print the hobbyist value of the 0 to 100 index data
# Print the Hobbyist to Employement values of the 0 to 100 index data

# %%
schema_df = pd.read_csv('/content/survey_results_schema.csv', index_col = 'Column')
schema_df.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
schema_df.loc['Hobbyist', 'QuestionText']
# Out:
# 'Do you code as a hobby?'

# %%
schema_df.sort_index()
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %%
df = pd.read_csv('/content/survey_results_public.csv', index_col='Respondent')
df.head(1)
# Out:
#                                         MainBranch Hobbyist OpenSourcer  \
# Respondent
# 1           I am a student who is learning to code      Yes       Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
#
#                                         Employment         Country Student  \
# Respondent
# 1           Not employed, and not looking for work  United Kingdom      No
#
#                               EdLevel UndergradMajor  \
# Respondent
# 1           Primary/elementary school            NaN
#
#                                                      EduOther  ...  \
# Respondent                                                     ...
# 1           Taught yourself a new language, framework, or ...  ...
#
#                                       WelcomeChange  \
# Respondent
# 1           Just as welcome now as I felt last year
#
# ...

# %%
df['Country'] == 'Nepal'
# Out:
# Respondent
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: Country, Length: 88883, dtype: bool

# %%
(df['Country'] == 'Nepal').value_counts()
# Out:
# Country
# False    88646
# True       237
# Name: count, dtype: int64

# %%
df[df['Country'] == 'Nepal']
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 508         I am a student who is learning to code      Yes
# 592                 I am a developer by profession      Yes
# 984                 I am a developer by profession      Yes
# 1355                I am a developer by profession      Yes
# 1783                I am a developer by profession      Yes
# ...                                            ...      ...
# 86618               I am a developer by profession      Yes
# 86742               I am a developer by profession      Yes
# 87231               I am a developer by profession      Yes
# 87568               I am a developer by profession      Yes
# 88543               I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 508                                                     Never
# 592                                                     Never
# ...

# %%
filt_nepal = df['Country'] == "Nepal"
df[filt_nepal]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 508         I am a student who is learning to code      Yes
# 592                 I am a developer by profession      Yes
# 984                 I am a developer by profession      Yes
# 1355                I am a developer by profession      Yes
# 1783                I am a developer by profession      Yes
# ...                                            ...      ...
# 86618               I am a developer by profession      Yes
# 86742               I am a developer by profession      Yes
# 87231               I am a developer by profession      Yes
# 87568               I am a developer by profession      Yes
# 88543               I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 508                                                     Never
# 592                                                     Never
# ...

# %%
df.loc[filt_nepal]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 508         I am a student who is learning to code      Yes
# 592                 I am a developer by profession      Yes
# 984                 I am a developer by profession      Yes
# 1355                I am a developer by profession      Yes
# 1783                I am a developer by profession      Yes
# ...                                            ...      ...
# 86618               I am a developer by profession      Yes
# 86742               I am a developer by profession      Yes
# 87231               I am a developer by profession      Yes
# 87568               I am a developer by profession      Yes
# 88543               I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 508                                                     Never
# 592                                                     Never
# ...

# %%
df.loc[filt_nepal, 'MgrIdiot']
# Out:
# Respondent
# 508                         NaN
# 592                         NaN
# 984          Somewhat confident
# 1355         Somewhat confident
# 1783       Not at all confident
#                   ...
# 86618      Not at all confident
# 86742        Somewhat confident
# 87231    I don't have a manager
# 87568        Somewhat confident
# 88543        Somewhat confident
# Name: MgrIdiot, Length: 237, dtype: object

# %%
df.loc[filt_nepal, 'MgrIdiot'].value_counts()
# Out:
# MgrIdiot
# Somewhat confident        66
# Very confident            28
# Not at all confident      23
# I don't have a manager     9
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.loc[filt_nepal, 'MgrIdiot'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='MgrIdiot'>

# %%
df.loc[filt_nepal, 'MgrIdiot'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## **Using & opeator for multiple queries**

# %% [markdown]
# ### **Who are the Nepalese who think their manager is acutally idiot?**

# %%
filt_idiot = (df['Country'] == 'Nepal') & (df['MgrIdiot'] == 'Not at all confident')
filt_idiot.head()
# Out:
# Respondent
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df.loc[filt_idiot]
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 1783        I am a developer by profession      Yes
# 4452        I am a developer by profession      Yes
# 8392        I am a developer by profession       No
# 8751        I am a developer by profession      Yes
# 9860        I am a developer by profession      Yes
# 12222       I am a developer by profession      Yes
# 16498       I am a developer by profession      Yes
# 25984       I am a developer by profession      Yes
# 29157       I am a developer by profession      Yes
# 32610       I am a developer by profession      Yes
# 40608       I am a developer by profession      Yes
# 41114       I am a developer by profession      Yes
# 52045       I am a developer by profession      Yes
# 60493       I am a developer by profession      Yes
# 61164          I code primarily as a hobby      Yes
# 63653       I am a developer by profession      Yes
# 68293       I am a developer by profession      Yes
# ...

# %%
df.loc[filt_idiot, 'ConvertedComp'] # manager annual USD salary
# Out:
# Respondent
# 1783      1692.0
# 4452         NaN
# 8392         NaN
# 8751         NaN
# 9860         NaN
# 12222        NaN
# 16498     1584.0
# 25984        NaN
# 29157     6852.0
# 32610     6324.0
# 40608     3168.0
# 41114     4992.0
# 52045     8436.0
# 60493        NaN
# 61164        NaN
# 63653        NaN
# 68293     4224.0
# 70768        NaN
# 73700     2220.0
# 79094     8788.0
# 81976     5268.0
# 84947     3696.0
# 86618    12000.0
# Name: ConvertedComp, dtype: float64

# %%
df.loc[filt_idiot, 'ConvertedComp'].mean()
# Out:
# 5326.461538461538

# %%
df.loc[filt_idiot, 'ConvertedComp'].median()
# Out:
# 4992.0

# %%
df.loc[filt_idiot, 'ConvertedComp'].sum()
# Out:
# 69244.0

# %%
df.loc[filt_idiot, 'ConvertedComp'].max()
# Out:
# 12000.0

# %%
df.loc[filt_idiot, 'ConvertedComp'].min()
# Out:
# 1584.0

# %%
schema_df.loc['WelcomeChange','QuestionText']
# Out:
# 'Compared to last year, how welcome do you feel on Stack Overflow?'

# %% [markdown]
# ## **groupby function**

# %%
country_group = df.groupby('Country')
country_group

# %%
country_group['SocialMedia'].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: count, Length: 1220, dtype: int64

# %%
country_group['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_group['SocialMedia'].value_counts().loc['Nepal']
# Out:
# SocialMedia
# YouTube                     95
# Facebook                    71
# LinkedIn                    22
# Twitter                     16
# Reddit                       9
# Instagram                    8
# WhatsApp                     5
# I don't use social media     4
# WeChat 微信                    1
# Name: count, dtype: int64

# %%
country_group['SocialMedia'].value_counts().loc['Nepal'].plot.pie()
# Out:
# <Axes: ylabel='count'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 24494 (\N{CJK UNIFIED IDEOGRAPH-5FAE}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 20449 (\N{CJK UNIFIED IDEOGRAPH-4FE1}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24494 (\N{CJK UNIFIED IDEOGRAPH-5FAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20449 (\N{CJK UNIFIED IDEOGRAPH-4FE1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
country_group['SocialMedia'].value_counts().loc['India'].plot.bar()
# Out:
# <Axes: xlabel='SocialMedia'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 24494 (\N{CJK UNIFIED IDEOGRAPH-5FAE}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 20449 (\N{CJK UNIFIED IDEOGRAPH-4FE1}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 20248 (\N{CJK UNIFIED IDEOGRAPH-4F18}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 37239 (\N{CJK UNIFIED IDEOGRAPH-9177}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 26032 (\N{CJK UNIFIED IDEOGRAPH-65B0}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
country_group['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
country_group['ConvertedComp'].median().loc['Nepal']
# Out:
# 4224.0

# %%
country_group['ConvertedComp'].median().loc['India']
# Out:
# 10080.0

# %%
country_group['ConvertedComp'].median().loc['Canada']
# Out:
# 68705.0

# %%
country_group['ConvertedComp'].agg(['mean','median','min','max']).loc['Canada']
# Out:
# mean      1.340186e+05
# median    6.870500e+04
# min       0.000000e+00
# max       2.000000e+06
# Name: Canada, dtype: float64

# %% [markdown]
# Some exercises
# Education Data Analysis
#
# Get the EdLevel data of Nepal
#
# Count and plot the EdLevel data of Nepal
#
# Perform grouping of countries and find the EdLevel data
#
# Compare the education status of developers from India and Nepal.
#
# Using agg function, compute the mean, median, max, and min data of age of all countries

# %%
country_group['EdLevel'].value_counts().loc['Nepal']
# Out:
# EdLevel
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              167
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     31
# Some college/university study without earning a degree                                 14
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                            10
# Associate degree                                                                        6
# Other doctoral degree (Ph.D, Ed.D., etc.)                                               2
# Primary/elementary school                                                               2
# I never completed any formal education                                                  1
# Name: count, dtype: int64

# %%
country_group['EdLevel'].value_counts().loc['Nepal'].plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
country_group['EdLevel'].value_counts()
# Out:
# Country      EdLevel
# Afghanistan  Bachelor’s degree (BA, BS, B.Eng., etc.)                                              17
#              Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     5
#              Associate degree                                                                       4
#              Primary/elementary school                                                              4
#              I never completed any formal education                                                 3
#                                                                                                    ..
# Zambia       Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     1
# Zimbabwe     Bachelor’s degree (BA, BS, B.Eng., etc.)                                              19
#              Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     9
# ...

# %%
india_edu_data=country_group['EdLevel'].value_counts().loc['India']
india_edu_data
# Out:
# EdLevel
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              5564
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           1877
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     701
# Some college/university study without earning a degree                                 283
# Primary/elementary school                                                               84
# Associate degree                                                                        74
# I never completed any formal education                                                  49
# Professional degree (JD, MD, etc.)                                                      43
# Other doctoral degree (Ph.D, Ed.D., etc.)                                               24
# Name: count, dtype: int64

# %%
nepal_edu_data=country_group['EdLevel'].value_counts().loc['Nepal']
nepal_edu_data
# Out:
# EdLevel
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              167
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     31
# Some college/university study without earning a degree                                 14
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                            10
# Associate degree                                                                        6
# Other doctoral degree (Ph.D, Ed.D., etc.)                                               2
# Primary/elementary school                                                               2
# I never completed any formal education                                                  1
# Name: count, dtype: int64

# %%
#alternative way to extract data
nepal_education=df.loc[df['Country']=='Nepal','EdLevel']
nepal_education
# Out:
# Respondent
# 508      Secondary school (e.g. American high school, G...
# 592      Some college/university study without earning ...
# 984               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1355              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1783              Bachelor’s degree (BA, BS, B.Eng., etc.)
#                                ...
# 86618             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 86742             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 87231             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 87568             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88543             Bachelor’s degree (BA, BS, B.Eng., etc.)
# Name: EdLevel, Length: 237, dtype: object

# %%
nepal_education.value_counts().plot.bar(color='Green')
# Out:
# <Axes: xlabel='EdLevel'>

# %%
nepal_education.value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
nepal_education.value_counts()
# Out:
# EdLevel
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              167
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     31
# Some college/university study without earning a degree                                 14
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                            10
# Associate degree                                                                        6
# Other doctoral degree (Ph.D, Ed.D., etc.)                                               2
# Primary/elementary school                                                               2
# I never completed any formal education                                                  1
# Name: count, dtype: int64

# %%
comparison_df = pd.DataFrame({
    'India': india_edu_data,
    'Nepal': nepal_edu_data
}).fillna(0)

# %%
comparison_df
# Out:
#                                                     India  Nepal
# EdLevel
# Associate degree                                       74    6.0
# Bachelor’s degree (BA, BS, B.Eng., etc.)             5564  167.0
# I never completed any formal education                 49    1.0
# Master’s degree (MA, MS, M.Eng., MBA, etc.)          1877   10.0
# Other doctoral degree (Ph.D, Ed.D., etc.)              24    2.0
# Primary/elementary school                              84    2.0
# Professional degree (JD, MD, etc.)                     43    0.0
# Secondary school (e.g. American high school, Ge...    701   31.0
# Some college/university study without earning a...    283   14.0

# %%
comparison_df.plot.bar()
# Out:
# <Axes: xlabel='EdLevel'>

# %%
age_stats = df.groupby('Country')['Age'].agg(['mean', 'median', 'max', 'min'])

print(age_stats)
# Out:
#                                            mean  median   max   min
# Country
# Afghanistan                           27.913043    25.0  85.0   1.0
# Albania                               25.145833    24.0  40.0  15.0
# Algeria                               27.284404    25.0  63.0   5.0
# Andorra                               28.000000    21.5  50.0  19.0
# Angola                                26.666667    23.0  35.0  22.0
# ...                                         ...     ...   ...   ...
# Venezuela, Bolivarian Republic of...  28.301205    25.0  61.0  17.0
# Viet Nam                              26.739884    25.0  99.0   1.0
# Yemen                                 28.117647    27.0  39.0  22.0
# Zambia                                28.000000    26.0  49.0  19.0
# Zimbabwe                              27.371429    26.0  46.0  20.0
#
# [179 rows x 4 columns]

# %%
age_stat=df.groupby("Country")['Age'].agg(['mean','median','max','min'])
age_stat
# Out:
#                                            mean  median   max   min
# Country
# Afghanistan                           27.913043    25.0  85.0   1.0
# Albania                               25.145833    24.0  40.0  15.0
# Algeria                               27.284404    25.0  63.0   5.0
# Andorra                               28.000000    21.5  50.0  19.0
# Angola                                26.666667    23.0  35.0  22.0
# ...                                         ...     ...   ...   ...
# Venezuela, Bolivarian Republic of...  28.301205    25.0  61.0  17.0
# Viet Nam                              26.739884    25.0  99.0   1.0
# Yemen                                 28.117647    27.0  39.0  22.0
# Zambia                                28.000000    26.0  49.0  19.0
# Zimbabwe                              27.371429    26.0  46.0  20.0
#
# [179 rows x 4 columns]

# %% [markdown]
# Some more analysis
# How many developers code as a hobby, and how does it vary across different countries? Hint: Hobbyist and Country
#
# What is the average number of years developers have been coding professionally? Hint: YearsCodePro
#
# How does job satisfaction vary based on the number of working hours per week? Hint: JobSat and WorkWeekHrs
#
# What are the most common web frameworks used by developers, and are there any preferences for the next year? Hint: WebFrameWorkedWith and WebFrameDesireNextYear
#
# Is there any relationship between compensation and the number of years of coding experience? Hint: ConvertedComp
#
# Do developers who work remotely report higher career satisfaction compared to those who don't? Hint: WorkRemote and JobSat
#
# What is the average age of developers across different countries, and how does it affect their career satisfaction? Hint: CareerSat

# %%
country_group

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %%
hobby_list=df['Hobbyist'].value_counts()
hobby_list
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
hobby_count=df[['Hobbyist']=='Yes'].groupby('Country')['Hobbyist'].value_counts()
hobby_count
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-139-08224f7e2753> in <cell line: 1>()
# ...
