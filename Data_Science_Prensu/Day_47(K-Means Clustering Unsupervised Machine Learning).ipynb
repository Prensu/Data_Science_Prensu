# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Live.csv")

# %%
df.head()
# Out:
#                           status_id status_type status_published  \
# 0  246675545449582_1649696485147474       video   4/22/2018 6:00
# 1  246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2  246675545449582_1648730588577397       video   4/21/2018 6:17
# 3  246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4  246675545449582_1645700502213739       photo   4/18/2018 3:22
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# ...

# %%
df.isnull().sum()
# Out:
# status_id              0
# status_type            0
# status_published       0
# num_reactions          0
# num_comments           0
# num_shares             0
# num_likes              0
# num_loves              0
# num_wows               0
# num_hahas              0
# num_sads               0
# num_angrys             0
# Column1             7050
# Column2             7050
# Column3             7050
# Column4             7050
# dtype: int64

# %%
df
# Out:
#                               status_id status_type status_published  \
# 0      246675545449582_1649696485147474       video   4/22/2018 6:00
# 1      246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2      246675545449582_1648730588577397       video   4/21/2018 6:17
# 3      246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4      246675545449582_1645700502213739       photo   4/18/2018 3:22
# ...                                 ...         ...              ...
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %% [markdown]
# df.info()

# %%
len(df['status_id'].unique())
# Out:
# 6997

# %%
df['status_published'].unique()
# Out:
# array(['4/22/2018 6:00', '4/21/2018 22:45', '4/21/2018 6:17', ...,
#        '9/21/2016 23:03', '9/20/2016 0:43', '9/10/2016 10:30'],
#       dtype=object)

# %%
len(df['status_published'].unique())
# Out:
# 6913

# %% [markdown]
# Since Status id and status published has large unique values so it is not possible to cluster ! We are droping them !

# %%
df.drop(['status_id','status_published'],axis=1,inplace=True)

# %%
df
# Out:
#      status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0          video            529           512         262        432
# 1          photo            150             0           0        150
# 2          video            227           236          57        204
# 3          photo            111             0           0        111
# 4          photo            213             0           0        204
# ...          ...            ...           ...         ...        ...
# 7045       photo             89             0           0         89
# 7046       photo             16             0           0         14
# 7047       photo              2             0           0          1
# 7048       photo            351            12          22        349
# 7049       photo             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   object
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 550.9+ KB

# %%
#now we are going to differentiate according to status_type ! We are going to form cluster according to the status type

# %%
x=df
y=df['status_type']

# %%
x.head()
# Out:
#   status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0       video            529           512         262        432         92
# 1       photo            150             0           0        150          0
# 2       video            227           236          57        204         21
# 3       photo            111             0           0        111          0
# 4       photo            213             0           0        204          9
#
#    num_wows  num_hahas  num_sads  num_angrys
# 0         3          1         1           0
# 1         0          0         0           0
# 2         1          1         0           0
# 3         0          0         0           0
# 4         0          0         0           0

# %%
y.head()
# Out:
# 0    video
# 1    photo
# 2    video
# 3    photo
# 4    photo
# Name: status_type, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder 
le=LabelEncoder()

# %%
x['status_type']=le.fit_transform(x['status_type'])

# %%
y=le.transform(y)

# %%
x.head()
# Out:
#    status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0            3            529           512         262        432         92
# 1            1            150             0           0        150          0
# 2            3            227           236          57        204         21
# 3            1            111             0           0        111          0
# 4            1            213             0           0        204          9
#
#    num_wows  num_hahas  num_sads  num_angrys
# 0         3          1         1           0
# 1         0          0         0           0
# 2         1          1         0           0
# 3         0          0         0           0
# 4         0          0         0           0

# %%
y
# Out:
# array([3, 1, 3, ..., 1, 1, 1])

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   int32
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
# dtypes: int32(1), int64(9)
# memory usage: 523.4 KB

# %%
x.tail()
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 7045            1             89             0           0         89
# 7046            1             16             0           0         14
# 7047            1              2             0           0          1
# 7048            1            351            12          22        349
# 7049            1             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 7045          0         0          0         0           0
# 7046          1         0          1         0           0
# 7047          1         0          0         0           0
# 7048          2         0          0         0           0
# 7049          0         0          0         0           0

# %%
x
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0               3            529           512         262        432
# 1               1            150             0           0        150
# 2               3            227           236          57        204
# 3               1            111             0           0        111
# 4               1            213             0           0        204
# ...           ...            ...           ...         ...        ...
# 7045            1             89             0           0         89
# 7046            1             16             0           0         14
# 7047            1              2             0           0          1
# 7048            1            351            12          22        349
# 7049            1             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %%
x['status_type'].unique()
# Out:
# array([3, 1, 0, 2])

# %%
cols=df.columns

# %%
cols
# Out:
# Index(['status_type', 'num_reactions', 'num_comments', 'num_shares',
#        'num_likes', 'num_loves', 'num_wows', 'num_hahas', 'num_sads',
#        'num_angrys'],
#       dtype='object')

# %%
x=pd.DataFrame(x)

# %%
x
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0               3            529           512         262        432
# 1               1            150             0           0        150
# 2               3            227           236          57        204
# 3               1            111             0           0        111
# 4               1            213             0           0        204
# ...           ...            ...           ...         ...        ...
# 7045            1             89             0           0         89
# 7046            1             16             0           0         14
# 7047            1              2             0           0          1
# 7048            1            351            12          22        349
# 7049            1             17             0           0         17
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0            92         3          1         1           0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()
x=ms.fit_transform(x)

# %%
x=pd.DataFrame(x,columns=[cols])

# %%
x
# Out:
#      status_type num_reactions num_comments num_shares num_likes num_loves  \
# 0       1.000000      0.112314     0.024393   0.076519  0.091720  0.140030
# 1       0.333333      0.031847     0.000000   0.000000  0.031847  0.000000
# 2       1.000000      0.048195     0.011243   0.016647  0.043312  0.031963
# 3       0.333333      0.023567     0.000000   0.000000  0.023567  0.000000
# 4       0.333333      0.045223     0.000000   0.000000  0.043312  0.013699
# ...          ...           ...          ...        ...       ...       ...
# 7045    0.333333      0.018896     0.000000   0.000000  0.018896  0.000000
# 7046    0.333333      0.003397     0.000000   0.000000  0.002972  0.001522
# 7047    0.333333      0.000425     0.000000   0.000000  0.000212  0.001522
# 7048    0.333333      0.074522     0.000572   0.006425  0.074098  0.003044
# 7049    0.333333      0.003609     0.000000   0.000000  0.003609  0.000000
#
#       num_wows num_hahas  num_sads num_angrys
# ...

# %%
# now we see the dataframe is between 0 & 1

# %%
from sklearn.cluster import KMeans

kmeans=KMeans(n_clusters=2,random_state=0)

# %%
kmeans
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=0) 
kmeans.fit(x)  # Assuming 'data' is your dataset

cluster_centers = kmeans.cluster_centers_

# %%
cluster_centers
# Out:
# array([[9.54921576e-01, 6.46330441e-02, 2.67028654e-02, 2.93171709e-02,
#         5.71231462e-02, 4.71007076e-02, 8.18581889e-03, 9.65207685e-03,
#         8.04219428e-03, 7.19501847e-03],
#        [3.28506857e-01, 3.90710874e-02, 7.54854864e-04, 7.53667113e-04,
#         3.85438884e-02, 2.17448568e-03, 2.43721364e-03, 1.20039760e-03,
#         2.75348016e-03, 1.45313276e-03]])

# %%
kmeans.inertia_
# Out:
# 237.75726404419547

# %%
labels=kmeans.labels_

# %%
correct_labels=sum(y==labels)

print("Result of the correct_labels: %d out of %d samples were correctly labelled :" %(correct_labels,y.size) )
# Out:
# Result of the correct_labels: 4288 out of 7050 samples were correctly labelled :

# %%
print('Accuracy_score: {0:0.2f}'.format(correct_labels/float(y.size)) )
# Out:
# Accuracy_score: 0.61

# %%
cs=[]
for i in range(1,11):
    k means=KMeans(n_clusters=i,init='k_means++', max_iter=300, n_init=
